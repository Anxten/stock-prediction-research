# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# Tentukan simbol (BBRI.JK) dan rentang waktu
symbol = "BBRI.JK"
start_date = "2019-01-01"
end_date = "2026-01-01"

# Download data
print(f"Sedang mendownload data {symbol}...")
df = yf.download(symbol, start=start_date, end=end_date)

# Tampilkan 5 data teratas
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Sedang mendownload data BBRI.JK...
# Price             Close         High          Low         Open     Volume
# Ticker          BBRI.JK      BBRI.JK      BBRI.JK      BBRI.JK    BBRI.JK
# Date
# 2019-01-01  2286.934326  2286.934326  2286.934326  2286.934326          0
# 2019-01-02  2255.691162  2274.436491  2243.194332  2255.691162   82441033
# 2019-01-03  2261.940186  2274.437018  2236.946352  2236.946352  102805905
# 2019-01-04  2286.934326  2286.934326  2255.691988  2261.940489  125907734
# 2019-01-07  2286.934326  2318.176497  2286.934326  2311.928163   82106628

# %%
# Pastikan folder data sudah ada
os.makedirs('../data', exist_ok=True)

# Simpan
df.to_csv('../data/BBRI_raw.csv')
print("Data berhasil disimpan di folder data/BBRI_raw.csv")
# Out:
# Data berhasil disimpan di folder data/BBRI_raw.csv

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'], color='blue', label='Harga Close')
plt.title(f'Tren Harga Saham {symbol} (2019 - Sekarang)')
plt.xlabel('Tahun')
plt.ylabel('Harga (IDR)')
plt.legend()
plt.grid(True)
plt.show()
